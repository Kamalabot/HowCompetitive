# %% [markdown]
# **Challenge**
#
# Implementing tree with an array?
#
# ![image.png](attachment:563d063b-8826-46ca-82bf-a10dde7dc7da.png)

# %% [markdown]
# Whats a Tree?
#
# Tree has a root, which has children. The children themselves have further nodes below.
#
# Tree is an Abstract Data Type (ADT). ADT is defined by a set of values and operations but doesn't mention how to implement. (Like the Trie)
#
# This means, **multiple ways to implement it** (4 ways discussed)

# %% [markdown]
# ** Linked List Implementation **
#
# ![image.png](attachment:989f2092-fd53-4b36-8e3c-e985204f95f4.png)

# %% [markdown]
# ** Using the Tuple**
#
# ![image.png](attachment:9014a214-e8c2-43e2-b3c8-93f17a504b03.png)

# %% [markdown]
# ![image.png](attachment:33077276-d2dd-4b65-8ef4-6d9a6ced5554.png)

# %% [markdown]
# ![image.png](attachment:ab5a0d3d-6c82-48f6-b553-fe4b27bd1564.png)

# %% [markdown]
# Its not efficient to implement tree as a array...
#
# Increases both Space and Time complexity...
#
# Binary heap is always implemented with array, because there will be no null values.
#
# ![image.png](attachment:825bccd2-87cb-4876-8283-96e0d275ec22.png)
