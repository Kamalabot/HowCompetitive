# %% [markdown]
# ### Challenge solved by Heap
#
# - Allows to store the data in the required priority
#
# ### Doing the same with Array:
#
# - Searching a string as array will be O(nm), while as Trie will O(m)
#
# ### Used in:
#
# - Auto complete application
#
# - Storing and Searching string
# -
# The trie data structure, which is used for efficient storage and retrieval of strings,is **not as commonly used in Python libraries** as some other data structures. However, there are libraries and modules that utilize trie-like structures or offer trie-related functionality. Here are a few Python libraries and modules that use or provide trie data structures or operations:
#
# PyTrie: PyTrie is a Python library specifically designed for implementing trie data structures and algorithms. It provides classes and methods for creating and working with tries.
#
# PyAutoGUI: PyAutoGUI is a library for automating GUI interactions. It includes a function called typewrite() that can simulate typing a string of characters, which may involve using a trie or similar data structure for efficient keyboard emulation.
#
# Trie Module in NLTK: The Natural Language Toolkit (NLTK) includes a Trie module that provides trie data structures and associated operations. It can be useful for natural language processing tasks.
#
# Autocomplete Libraries: Some autocomplete and suggestion libraries may use trie-like structures to efficiently suggest words or phrases as the user types. These libraries may include their own implementations or use trie-related algorithms.
#
# Spell Checkers: Libraries or modules that implement spell-checking functionality may use trie structures to store and search for valid words or suggestions during spell checking.
#
# Networking and Routing: In networking and routing libraries, trie structures may be used for IP address or URL routing, allowing for efficient lookup and matching of network addresses.
#
# Domain Name Resolution: DNS resolver libraries or modules may employ trie-like structures for domain name resolution, helping translate domain names into IP addresses quickly.
#
# Search Engines: Some search engine implementations or libraries for indexing and searching documents may use trie structures for efficient text search and retrieval.
#
# Keyword and Command Parsing: Libraries for parsing keywords or command-line arguments efficiently may use trie-like structures to match and execute commands or recognize keywords.
#
# Machine Learning and Text Processing: In certain machine learning and text processing tasks, tries or trie-inspired structures may be used to efficiently organize and search through large text corpora.
#
# Please note that while trie data structures themselves are not as prevalent in Python libraries, trie-related algorithms and techniques can be found in various applications and domains, especially those involving text processing, natural language processing, and efficient searching and retrieval of strings.

# %% [markdown]
# ![image.png](attachment:12aacf5a-2a5c-4728-be72-54fe103dd981.png)

# %% [markdown]
# ![image.png](attachment:c21a94eb-b512-4b6f-b9bc-bb40639f1d6e.png)

# %% [markdown]
# ![image.png](attachment:a255ac98-881f-4642-aad6-e3035a52dedd.png)

# %% [markdown]
# ![image.png](attachment:156dc1e5-81fe-418b-8518-fc75d766e342.png)

# %% [markdown]
# ![image.png](attachment:eeb3b05e-fb0f-46c5-9abe-33ccd15ec7f4.png)

# %% [markdown]
# ![image.png](attachment:d8de28fd-5e21-45b4-9552-1737376c6f32.png)

# %% [markdown]
# ![image.png](attachment:71ca9259-22d8-4800-9b08-698f9447e156.png)

# %% [markdown]
# ![image.png](attachment:d9d7f1f6-b6d6-42a9-a6a6-ac2db4c0966b.png)
