# %% [markdown]
# ### Challenge solved by Heap
#
# - Allows to store the data in the required priority
#
# - Allows to insert the data, while in the backend it takes care of the priority
#
# ### Doing the same with Array:
#
# - Will lead O(nlogn) complexity to create and sort array
#
# - O(n) complexity to insert a new element and still maintain the index
#
# ### Used in:
#
# - Prim's algorithm
#
# - Djikastra algorithm
#
# - Huffman coding algorithm

# %% [markdown]
# ![image.png](attachment:3c2141dc-66c1-48c5-acee-1ffb295edd2f.png)
#
# Root is always the minimum or maximum

# %% [markdown]
# ![image.png](attachment:28ef9ce8-9b81-4f8e-ab25-079c345a0349.png)

# %% [markdown]
# ![image.png](attachment:beecbb27-94c4-44a3-95df-431da04128fc.png)

# %% [markdown]
# ![image.png](attachment:e32e98c7-e66a-4d46-b558-9863bd869bdf.png)
