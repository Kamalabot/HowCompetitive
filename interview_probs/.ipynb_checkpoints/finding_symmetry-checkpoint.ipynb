# %% [markdown]
# ### Problem 4:
#
# Given a Binary Tree, check if its symmetric around its center

# %% [markdown]
# ### Ideas / Solutions:
#
# Step 1: Decide the conditions that needs to be met for the roots to be symmetric, and list it down
#
# step 2: After traversing to the one level down the tree, the recursive solution is implemented

# %% [markdown]
# ![image.png](attachment:95a467ca-e589-4be1-84c4-b1ebd80b0760.png)

# %% [markdown]
# ### Implementation Challenges
#
# Ch_1: Understand how to implement tree in Python first...
#
# Ch_2: Understand how the depth first search is implemented, as its used in majority cases
#
# Ch_3: Learn the discipline of walking through the problem and identifying the condition. Most of the time, that is all it takes to move to the solution

# %% [markdown]
# ### Where can be used in real world?
#
# Determining whether a tree is symmetric, often referred to as checking for symmetry or mirroring, has practical applications in various fields where hierarchical or structural relationships need to be verified. Here are some real-world applications:
#
# **Syntax Tree Validation:** In programming languages and compilers, syntax trees are often checked for symmetry to ensure that code follows the correct grammar rules.
# Binary Search Tree Verification: Symmetry checks can be used to validate if a binary search tree is correctly structured.
#
# **Network Topology Analysis:** In network analysis, determining if a network or graph is symmetric can help identify redundant links or connections in a network.
# Symmetry Detection in Graphs: Symmetric graphs have applications in areas like chemistry (molecular symmetry) and crystallography (crystal structure analysis).
#
# **Medical Imaging:** In medical imaging, detecting symmetric structures in images, such as organs or bones, can aid in diagnosis and analysis.
# Pattern Recognition: Symmetry detection is used in computer vision for recognizing symmetrical objects or patterns in images.
#
# **Sensor Fusion:** In robotics, sensors often provide data about the environment, and symmetry checks can help in merging and processing sensor data for localization and mapping.
# Path Planning: Symmetry detection can assist in determining optimal paths for robot navigation by identifying symmetrical landmarks.
#
# **Syntax Tree Parsing:** In NLP, syntax trees are analyzed for symmetry to understand the grammatical structure of sentences and phrases.

# %%
# Tree traversal requires a tree first. Which i need to understand how to create first

def are_symmetric(root1,root2):
    if root1 is None and root2 is None:
        return True
    elif((root is None) != (root2 is None)) or root1.val != root2.val:
        return False
    else:
        return are_symmetric(root1.left, root2.right) and are_symmetric(root1.right, root2.left)

# %%
def is_symmetric(root):
    if root is None:
        return True
    return are_symmetric(root.left,root.right)
