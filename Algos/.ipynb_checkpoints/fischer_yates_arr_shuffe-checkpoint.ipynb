# %% [markdown]
# ### Shuffling the array!!!
#
# How?
#
# New array has to be same length of the current one.
#
# random number can be called between 0 and len(curr_arr) and used has index to locate the number in current array, and place it current position.
#
# Before that ensure the same number is not occurring more times than it occurs in curr_arr.

# %% [markdown]
# In the above steps,
#
# Once a element is chosen, its popped from the curr_arr
#
# Length of array is reduced when looking for the random number...

# %% [markdown]
# ## O(n^2) complexity
#
# ![image.png](attachment:ee0f15cf-6752-4d3b-b940-7c580d452fb5.png)

# %% [markdown]
# ![image.png](attachment:d85d181b-10e5-4dae-9d0a-66bf0b8380bd.png)
#
# ![image.png](attachment:36a610f9-a054-4928-b629-63b0a4e49bcd.png)

# %% [markdown]
# ### Modern Fischer Yates
#
# ![image.png](attachment:f33f97d9-58ea-402b-99ae-4a4daf8df965.png)
#
# ![image.png](attachment:5339dfbb-eae1-464f-9192-3b499570ffb4.png)
#
# ![image.png](attachment:33f28940-983c-4ec2-8bd6-6d4581cf0566.png)

# %% [markdown]
# ![image.png](attachment:841d402d-1759-49bb-8f04-e1cb3af83bcf.png)
#
# ### O(n) complexity
#
# ![image.png](attachment:af3e8b83-ca9a-446d-9c2a-10f056075927.png)
