# %% [markdown]
# ## How to multiply two large numbers

# %% [markdown]
# Karatsuba algorithm is used, where the given numbers are divided into halves, and then they are multiplied. Its a "Divide & Conquer Algorithm"

# %% [markdown]
# ### Logic discussion
#
# ![image.png](attachment:9b52b89e-cdf5-491c-bd00-ec44edf7b8fa.png)
#
# ![image.png](attachment:827e47b5-4284-4320-9c88-a8c565002d86.png)
#
# ![image.png](attachment:f8a6f873-d4d1-457c-8601-715083e12d1a.png)

# %% [markdown]
# ## Implementation
#
# ![image.png](attachment:f5498cc9-6b24-4f8c-9d3f-93db32c94c8b.png)

# %% [markdown]
# ## Time complexity
#
# ![image.png](attachment:486d413e-c606-4695-aa64-5a903fbeda4f.png)

# %% [markdown]
# ### How the algorithm fits
#
# ![image.png](attachment:05c00cd7-f945-49e9-bfa5-fa2c6d8dcd68.png)
